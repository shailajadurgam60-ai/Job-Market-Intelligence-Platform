# %%
import os

print(os.getcwd())
# Out:
# /home/user/Documents/Job-Market-Intelligence-Platform/notebooks

# %%
import os

print(os.listdir("../data"))
# Out:
# ['clean_jobs.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/clean_jobs.csv")
df.head()
# Out:
#    id            title    company           location  \
# 0   1     Data Analyst       Meta       New York, NY
# 1   2     Data Analyst       Meta  San Francisco, CA
# 2   3     Data Analyst       Meta    Los Angeles, CA
# 3   4     Data Analyst       Meta     Washington, DC
# 4   5  Data Analyst II  Pinterest        Chicago, IL
#
#                                                 link    source date_posted  \
# 0  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 1  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 2  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 3  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 4  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-16
#
#    work_type  employment_type  \
# 0        NaN              NaN
# 1        NaN              NaN
# 2        NaN              NaN
# 3        NaN              NaN
# 4        NaN              NaN
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'work_type', 'employment_type', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   object
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
df.describe()
# Out:
#                 id  work_type  employment_type
# count  1048.000000        0.0              0.0
# mean   1314.083969        NaN              NaN
# std     772.822422        NaN              NaN
# min       1.000000        NaN              NaN
# 25%     616.750000        NaN              NaN
# 50%    1303.500000        NaN              NaN
# 75%    2033.250000        NaN              NaN
# max    2534.000000        NaN              NaN

# %%
df.shape
# Out:
# (1048, 10)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'title',
#  'company',
#  'location',
#  'link',
#  'source',
#  'date_posted',
#  'work_type',
#  'employment_type',
#  'description']

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# **** *******                           9
# Name: count, dtype: int64

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Meta        70
# Netflix     33
# Amazon      18
# Google      16
# ****        14
# Lensa        9
# TikTok       8
# AARATECH     8
# ********     8
# *****        7
# Name: count, dtype: int64

# %%
df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# Seattle, WA                        15
# London, England, United Kingdom    15
# London Area, United Kingdom        14
# Austin, TX                         13
# Gurugram, Haryana, India           13
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# title                 0
# company               2
# location             15
# link                  0
# source               89
# date_posted          23
# work_type          1048
# employment_type    1048
# description           4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["date_posted"] = pd.to_datetime(
    df["date_posted"],
    errors="coerce"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   datetime64[ns]
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 82.0+ KB

# %%
df["company"] = df["company"].fillna("Unknown")
df["location"] = df["location"].fillna("Unknown")
df["source"] = df["source"].fillna("Unknown")
df["description"] = df["description"].fillna("")

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
df.isnull().sum()
# Out:
# id                    0
# title                 0
# company               0
# location              0
# link                  0
# source                0
# date_posted          23
# work_type          1048
# employment_type    1048
# description           0
# dtype: int64

# %%
df["employment_type"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["employment_type"].unique()
# Out:
# array([nan])

# %%
df.drop(columns=["employment_type", "work_type"], inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description'],
#       dtype='object')

# %%
df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# **** *******                           9
# Name: count, dtype: int64

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Meta        70
# Netflix     33
# Amazon      18
# Google      16
# ****        14
# Lensa        9
# AARATECH     8
# TikTok       8
# ********     8
# *****        7
# Name: count, dtype: int64

# %%
df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# London, England, United Kingdom    15
# Seattle, WA                        15
# Unknown                            15
# London Area, United Kingdom        14
# Gurugram, Haryana, India           13
# Name: count, dtype: int64

# %%
df[df["company"] == "****"].head()
# Out:
#        id                             title company  \
# 618  1610               ****** **** *******    ****
# 619  1611  **** *******, ****** ***********    ****
# 633  1643                    **** *********    ****
# 643  1669          **** ********, *********    ****
# 644  1670          **** ********, *********    ****
#
#                          location  \
# 618  ********** **-********* ****
# 619                ***** ****, **
# 633                  *** ****, **
# 643               *** *******, **
# 644                ***** ****, **
#
#                                                   link    source date_posted  \
# 618  https://www.linkedin.com/jobs/view/people-data...  LinkedIn  2025-05-29
# 619  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-05-30
# 633  https://www.linkedin.com/jobs/view/data-scient...  LinkedIn  2025-06-02
# 643  https://www.linkedin.com/jobs/view/data-engine...  LinkedIn  2025-05-31
# ...

# %%
masked_companies = df["company"].str.contains(r"\*", regex=True, na=False).sum()
masked_titles = df["title"].str.contains(r"\*", regex=True, na=False).sum()
masked_locations = df["location"].str.contains(r"\*", regex=True, na=False).sum()

print("Masked companies:", masked_companies)
print("Masked titles:", masked_titles)
print("Masked locations:", masked_locations)
# Out:
# Masked companies: 72
# Masked titles: 72
# Masked locations: 72

# %%
print("Oldest Job:", df["date_posted"].min())
print("Newest Job:", df["date_posted"].max())
# Out:
# Oldest Job: 2025-04-10 00:00:00
# Newest Job: 2025-06-11 00:00:00

# %%
analysis_df = df.copy()

# %%
analysis_df = analysis_df[
    ~analysis_df["company"].str.contains(r"\*", regex=True, na=False)
]

analysis_df = analysis_df[
    ~analysis_df["title"].str.contains(r"\*", regex=True, na=False)
]

analysis_df = analysis_df[
    ~analysis_df["location"].str.contains(r"\*", regex=True, na=False)
]

# %%
analysis_df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
analysis_df["company"].value_counts().head(10)
# Out:
# company
# Meta         70
# Netflix      33
# Amazon       18
# Google       16
# Lensa         9
# AARATECH      8
# TikTok        8
# Handshake     7
# Uplers        6
# FanDuel       6
# Name: count, dtype: int64

# %%
analysis_df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# AI/ML Engineer                         9
# Name: count, dtype: int64

# %%
analysis_df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# Unknown                            15
# Seattle, WA                        15
# London, England, United Kingdom    15
# London Area, United Kingdom        14
# Austin, TX                         13
# Name: count, dtype: int64

# %%
df.iloc[0]
# Out:
# id                                                             1
# title                                               Data Analyst
# company                                                     Meta
# location                                            New York, NY
# link           https://www.linkedin.com/jobs/view/data-analys...
# source                                                  LinkedIn
# date_posted                                  2025-04-14 00:00:00
# description    The Social Measurement team is a growing team ...
# Name: 0, dtype: object

# %%
df.iloc[5]
# Out:
# id                                                             6
# title                                               Data Analyst
# company                                                  FanDuel
# location                                            New York, NY
# link           https://www.linkedin.com/jobs/view/data-analys...
# source                                                  LinkedIn
# date_posted                                  2025-04-11 00:00:00
# description    About Fanduel\n\nFanDuel Group is the premier ...
# Name: 5, dtype: object

# %%
df["company"].iloc[10]
# Out:
# 'Pinterest'

# %%
df["title"].iloc[20]
# Out:
# 'Analytics Associate'

# %%
df["description_clean"] = df["description"].str.lower()

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
df["description_clean"].iloc[0]
# Out:
# 'h'

# %%
df.shape
# Out:
# (1048, 9)

# %%
skills = [
    "python",
    "sql",
    "excel",
    "power bi",
    "tableau",
    "aws",
    "azure",
    "google cloud",
    "pandas",
    "numpy",
    "scikit-learn",
    "tensorflow",
    "pytorch",
    "machine learning",
    "deep learning",
    "statistics",
    "spark",
    "hadoop",
    "docker",
    "kubernetes",
    "git",
    "linux"
]
all_skills = []
df["description_clean"] = df["description_clean"].fillna("")
for i in range(len(df)):
    current_job_skills = []
    description=df["description_clean"].iloc[i]
    for skill in skills:
        if skill in description:
            current_job_skills.append(skill)
    all_skills.append(current_job_skills)

# %%
all_skills
# Out:
# [['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['python', 'sql'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['python', 'sql', 'excel', 'tableau', 'git'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['sql', 'machine learning', 'git'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['sql', 'excel', 'power bi', 'tableau'],
#  ['sql', 'excel', 'statistics', 'git'],
#  ['python', 'sql', 'excel', 'machine learning', 'statistics', 'spark'],
#  ['excel', 'statistics'],
#  ['sql', 'power bi', 'statistics'],
#  ['sql', 'excel', 'tableau'],
#  ['python', 'excel', 'tableau', 'git'],
# ...

# %%
len(all_skills)
# Out:
# 1048

# %%
df["extracted_skills"] = all_skills

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
#df["description_clean"].isna().sum()
# Out:
# np.int64(4)

# %%
df[["title", "extracted_skills"]].head(10)
# Out:
#                                                title  \
# 0                                       Data Analyst
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4                                    Data Analyst II
# 5                                       Data Analyst
# 6  Data Analyst, Production Finance Operations & ...
# 7                           Data Analyst - Marketing
# 8                                       Data Analyst
# 9                                    Data Analyst II
#
#                                     extracted_skills
# 0  [python, sql, tableau, machine learning, stati...
# 1  [python, sql, tableau, machine learning, stati...
# 2  [python, sql, tableau, machine learning, stati...
# 3  [python, sql, tableau, machine learning, stati...
# 4                     [python, sql, aws, statistics]
# 5                 [python, sql, excel, tableau, aws]
# ...

# %%
print(df["description_clean"].iloc[0][:300])
# Out:
# the social measurement team is a growing team with high-visibility within the communications organization that is being tasked with measuring the efficacy and impact of our social-first communications and marketing efforts. you'll play a unique role in shaping the way we approach reporting, define s

# %%
print(df["description_clean"].iloc[1][:300])
# Out:
# the social measurement team is a growing team with high-visibility within the communications organization that is being tasked with measuring the efficacy and impact of our social-first communications and marketing efforts. you'll play a unique role in shaping the way we approach reporting, define s

# %%
df[["title", "company", "description_clean"]].iloc[0:5]
# Out:
#              title    company  \
# 0     Data Analyst       Meta
# 1     Data Analyst       Meta
# 2     Data Analyst       Meta
# 3     Data Analyst       Meta
# 4  Data Analyst II  Pinterest
#
#                                    description_clean
# 0  the social measurement team is a growing team ...
# 1  the social measurement team is a growing team ...
# 2  the social measurement team is a growing team ...
# 3  the social measurement team is a growing team ...
# 4  about pinterest\n\nmillions of people around t...

# %%
df[["location", "date_posted"]].head(5)
# Out:
#             location date_posted
# 0       New York, NY  2025-04-14
# 1  San Francisco, CA  2025-04-14
# 2    Los Angeles, CA  2025-04-14
# 3     Washington, DC  2025-04-14
# 4        Chicago, IL  2025-04-16

# %%
df[["link"]].head(5)
# Out:
#                                                 link
# 0  https://www.linkedin.com/jobs/view/data-analys...
# 1  https://www.linkedin.com/jobs/view/data-analys...
# 2  https://www.linkedin.com/jobs/view/data-analys...
# 3  https://www.linkedin.com/jobs/view/data-analys...
# 4  https://www.linkedin.com/jobs/view/data-analys...

# %%
df.iloc[0]
# Out:
# id                                                                   1
# title                                                     Data Analyst
# company                                                           Meta
# location                                                  New York, NY
# link                 https://www.linkedin.com/jobs/view/data-analys...
# source                                                        LinkedIn
# date_posted                                        2025-04-14 00:00:00
# work_type                                                          NaN
# employment_type                                                    NaN
# description          The Social Measurement team is a growing team ...
# description_clean    the social measurement team is a growing team ...
# extracted_skills     [python, sql, tableau, machine learning, stati...
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# id                                                                   2
# title                                                     Data Analyst
# company                                                           Meta
# location                                             San Francisco, CA
# link                 https://www.linkedin.com/jobs/view/data-analys...
# source                                                        LinkedIn
# date_posted                                        2025-04-14 00:00:00
# work_type                                                          NaN
# employment_type                                                    NaN
# description          The Social Measurement team is a growing team ...
# description_clean    the social measurement team is a growing team ...
# extracted_skills     [python, sql, tableau, machine learning, stati...
# Name: 1, dtype: object

# %%
df[["company", "title", "extracted_skills"]].sample(10, random_state=42)
# Out:
#                        company  \
# 352                        Arc
# 984                 John Deere
# 876                      Petco
# 982                    Virtusa
# 31                        Salt
# 448                   Experian
# 198                       Meta
# 424  A.C.Camargo Cancer Center
# 107                 Aer Lingus
# 712                   H3C, LLC
#
#                                                  title  \
# 352                                       Data Analyst
# 984  Infrastructure Engineer III - Data Center e En...
# 876                            Assistant Store Manager
# 982                                      Data Engineer
# 31                                        Data Analyst
# 448        Data Scientist, Customer Analytics (Remote)
# 198                  Data Scientist, Product Analytics
# 424                               Analista Cadastro II
# 107                                       Data analyst
# 712                                       Data Analyst
#
# ...

# %%
skill_count = {}

for skills in df["extracted_skills"]:
    for skill in skills:
        if skill in skill_count:
            skill_count[skill] += 1
        else:
            skill_count[skill] = 1

# %%
list(skill_count.items())[:10]
# Out:
# [('python', 700),
#  ('sql', 759),
#  ('tableau', 273),
#  ('machine learning', 377),
#  ('statistics', 313),
#  ('git', 359),
#  ('aws', 305),
#  ('excel', 491),
#  ('power bi', 212),
#  ('spark', 232)]

# %%
sorted_skills = sorted(
    skill_count.items(),
    key=lambda x: x[1],
    reverse=True
)

# %%
print(sorted_skills)
# Out:
# [('sql', 759), ('python', 700), ('excel', 491), ('machine learning', 377), ('git', 359), ('statistics', 313), ('aws', 305), ('tableau', 273), ('spark', 232), ('power bi', 212), ('azure', 164), ('pytorch', 71), ('hadoop', 66), ('tensorflow', 65), ('deep learning', 65), ('google cloud', 53), ('kubernetes', 53), ('docker', 50), ('pandas', 48), ('scikit-learn', 45), ('numpy', 34), ('linux', 21)]

# %%
skill_df = pd.DataFrame(
    sorted_skills,
    columns=["skill", "count"]
)

# %%
skill_df
# Out:
#                skill  count
# 0                sql    759
# 1             python    700
# 2              excel    491
# 3   machine learning    377
# 4                git    359
# 5         statistics    313
# 6                aws    305
# 7            tableau    273
# 8              spark    232
# 9           power bi    212
# 10             azure    164
# 11           pytorch     71
# 12            hadoop     66
# 13        tensorflow     65
# 14     deep learning     65
# 15      google cloud     53
# 16        kubernetes     53
# 17            docker     50
# 18            pandas     48
# 19      scikit-learn     45
# 20             numpy     34
# 21             linux     21

# %%
top10 = skill_df.head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select Top 10 skills
top10 = skill_df.head(10)

# Create figure
plt.figure(figsize=(10,6))

# Create horizontal bar chart
ax = sns.barplot(
    data=top10,
    x="count",
    y="skill",
    color="steelblue"
)

# Add title and labels
plt.title("Top 10 Most Demanded Skills", fontsize=16, fontweight="bold")
plt.xlabel("Number of Job Postings", fontsize=12)
plt.ylabel("Skill", fontsize=12)

# Add value labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d", padding=5)

# Add grid on x-axis
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("top10_skills.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()

# Display plot
plt.show()

# %%
data_analyst_df = df[
    df["title"].str.contains("Data Analyst", case=False, na=False)
]

# %%
data_analyst_df
# Out:
#         id                        title                          company  \
# 0        1                 Data Analyst                             Meta
# 1        2                 Data Analyst                             Meta
# 2        3                 Data Analyst                             Meta
# 3        4                 Data Analyst                             Meta
# 4        5              Data Analyst II                        Pinterest
# ...    ...                          ...                              ...
# 960   2366               Data Analyst V  Texas Health and Human Services
# 1003  2443                 Data Analyst                Buckingham Search
# 1012  2459  Data Analyst - Construction                        Swinerton
# 1015  2462          Junior Data Analyst                          ManTech
# 1016  2463          Junior Data Analyst                            Lensa
#
#                location                                               link  \
# ...

# %%
data_analyst_df[["title", "company"]].head(10)
# Out:
#                                                title      company
# 0                                       Data Analyst         Meta
# 1                                       Data Analyst         Meta
# 2                                       Data Analyst         Meta
# 3                                       Data Analyst         Meta
# 4                                    Data Analyst II    Pinterest
# 5                                       Data Analyst      FanDuel
# 6  Data Analyst, Production Finance Operations & ...      Netflix
# 7                           Data Analyst - Marketing      FanDuel
# 8                                       Data Analyst  SBH Fashion
# 9                                    Data Analyst II    Pinterest

# %%
def count_skills(dataframe):
    
    skill_count = {}

    for skills in dataframe["extracted_skills"]:
        for skill in skills:
            if skill in skill_count:
                skill_count[skill] += 1
            else:
                skill_count[skill] = 1

    return skill_count

# %%
analyst_skill_count=count_skills(data_analyst_df)

# %%
list(analyst_skill_count.items())[:10]
# Out:
# [('python', 139),
#  ('sql', 232),
#  ('tableau', 136),
#  ('machine learning', 40),
#  ('statistics', 104),
#  ('git', 68),
#  ('aws', 48),
#  ('excel', 164),
#  ('power bi', 112),
#  ('spark', 21)]

# %%
sorted_analyst_skills=sorted(
    analyst_skill_count.items(),
    key=lambda x: x[1],
    reverse=True
)[:10]

# %%
analyst_df=pd.DataFrame(sorted_analyst_skills,columns=["skill","count"])

# %%
analyst_df
# Out:
#               skill  count
# 0               sql    232
# 1             excel    164
# 2            python    139
# 3           tableau    136
# 4          power bi    112
# 5        statistics    104
# 6               git     68
# 7               aws     48
# 8  machine learning     40
# 9             azure     24

# %%
top10 = analyst_df.nlargest(10, "count")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select Top 10 skills
top10 = analyst_df.head(10)

# Create figure
plt.figure(figsize=(10,6))

# Create horizontal bar chart
ax = sns.barplot(
    data=top10,
    x="count",
    y="skill",
    color="steelblue"
)

# Add title and labels
plt.title("Top 10 Skills for Data Analyst Jobs ", fontsize=16, fontweight="bold")
plt.xlabel("Number of Job Postings", fontsize=12)
plt.ylabel("Skill", fontsize=12)
plt.xlim(0, top10["count"].max() * 1.1)

# Add value labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d", padding=5)

# Add grid on x-axis
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("Data_Analyst_top10_skills.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()

# Display plot
plt.show()

# %%
data_scientist_df = df[
    df["title"].str.contains("Data Scientist", case=False, na=False)
]

# %%
scientist_skill_count = count_skills(data_scientist_df)

# %%
data_scientist_df
# Out:
#         id                                              title        company  \
# 116    377                  Data Scientist, Product Analytics           Meta
# 117    378            Data Scientist, Product, Sustainability         Google
# 118    379                  Data Scientist, Product Analytics           Meta
# 119    380                  Data Scientist, Product Analytics           Meta
# 120    381                               Fraud Data Scientist          ID.me
# ...    ...                                                ...            ...
# 1017  2476                                     Data Scientist      Terna SpA
# 1018  2478            Data Scientist (L5) - Ads (Forecasting)        Netflix
# 1019  2481  Data Scientist (Python) - Mumbai - Assistant V...           Citi
# 1045  2532  Vice President Data Scientist Marketing Analyt...  JPMorganChase
# 1046  2533           Lead Data Scientist - Finance Technology  JPMorganChase
#
#                         location  \
# ...

# %%
sorted_scientist_skills=sorted(
    scientist_skill_count.items(),
    key=lambda x: x[1],
    reverse=True
)[:10]

# %%
data_scientist_df=pd.DataFrame(sorted_scientist_skills,columns=["skill","count"])

# %%
data_scientist_df
# Out:
#               skill  count
# 0            python    181
# 1               sql    154
# 2  machine learning    140
# 3        statistics    119
# 4               git     85
# 5             excel     68
# 6               aws     44
# 7           tableau     42
# 8             spark     42
# 9     deep learning     25

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select Top 10 skills
top10 = data_scientist_df.head(10)

# Create figure
plt.figure(figsize=(10,6))

# Create horizontal bar chart
ax = sns.barplot(
    data=top10,
    x="count",
    y="skill",
    color="steelblue"
)

# Add title and labels
plt.title("Top 10 Skills for Data Scientist Jobs ", fontsize=16, fontweight="bold")
plt.xlabel("Number of Job Postings", fontsize=12)
plt.ylabel("Skill", fontsize=12)
plt.xlim(0, top10["count"].max() * 1.1)

# Add value labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d", padding=5)

# Add grid on x-axis
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("Data_Scientist_top10_skills.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()

# Display plot
plt.show()

# %%
data_engineer_df = df[
    df["title"].str.contains("Data Engineer", case=False, na=False)
]

# %%
engineer_skill_count = count_skills(data_engineer_df)

# %%
sorted_engineer_skills=sorted(
    engineer_skill_count.items(),
    key=lambda x: x[1],
    reverse=True
)[:10]

# %%
data_engineer_df=pd.DataFrame(sorted_engineer_skills,columns=["skill","count"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select Top 10 skills
top10 = data_engineer_df.head(10)

# Create figure
plt.figure(figsize=(10,6))

# Create horizontal bar chart
ax = sns.barplot(
    data=top10,
    x="count",
    y="skill",
    color="steelblue"
)

# Add title and labels
plt.title("Top 10 Skills for Data Engineer Jobs ", fontsize=16, fontweight="bold")
plt.xlabel("Number of Job Postings", fontsize=12)
plt.ylabel("Skill", fontsize=12)
plt.xlim(0, top10["count"].max() * 1.1)

# Add value labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d", padding=5)

# Add grid on x-axis
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("Data_Engineer_top10_skills.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()

# Display plot
plt.show()
